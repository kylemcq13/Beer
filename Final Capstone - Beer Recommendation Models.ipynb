# %% [markdown]
# # Final Capstone - Recommendation Models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
import statsmodels.api as sm
import seaborn as sns
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import normalize
# %matplotlib inline
from sklearn import neighbors
from sklearn.model_selection import cross_val_score
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import re
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
from pylab import *
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\kylem\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\kylem\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#upload the us_brewery_reviews dataset from the previous EDA notebook
beer = pd.read_csv(r'F:\Datasets\us_brewery_reviews.csv')

# %%
#preview the dataset
pd.set_option('display.max_columns', None)
beer.head()
# Out:
#    Unnamed: 0  beer_id         username        date  \
# 0           0   115317     KrajDoesBeer  2015-04-17
# 1           2   115317         Mmart802  2016-04-22
# 2           7   115317           Edmuzz  2016-04-15
# 3           8   115317          Lelandt  2016-04-07
# 4          16   115317  PittstopBrewing  2016-04-14
#
#                                                 text  look  smell  taste  \
# 0  10.24 batch. citra all in the nose.. some dank...  5.00   5.00    5.0
# 1  This beer was a real treat. Lots of sweet hop ...  5.00   4.75    5.0
# 2  This is a wonderful offering from MBC. While I...  5.00   4.75    5.0
# 3               Amazing. That's the only word for it  4.75   5.00    5.0
# 4  Most likely the best beer I have ever had. Sme...  5.00   5.00    5.0
#
#    feel  overall  score beer_name  brewery_id state country            style  \
# 0  4.75      5.0   4.98    Dinner       20681    ME      US  New England IPA
# 1  4.75      5.0   4.92    Dinner       20681    ME      US  New England IPA
# 2  4.75      5.0   4.92    Dinner       20681    ME      US  New England IPA
# 3  5.00      5.0   4.99    Dinner       20681    ME      US  New England IPA
# 4  5.00      5.0   5.00    Dinner       20681    ME      US  New England IPA
#
#   availability  abv                                         beer_notes  \
# 0     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 1     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 2     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 3     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 4     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
#
#   retired        brewery_name      city           brewery_notes  \
# 0       f  Maine Beer Company  Freeport  No notes at this time.
# 1       f  Maine Beer Company  Freeport  No notes at this time.
# 2       f  Maine Beer Company  Freeport  No notes at this time.
# 3       f  Maine Beer Company  Freeport  No notes at this time.
# 4       f  Maine Beer Company  Freeport  No notes at this time.
#
#                       types  \
# 0  Brewery, Bar, Beer-to-go
# 1  Brewery, Bar, Beer-to-go
# 2  Brewery, Bar, Beer-to-go
# 3  Brewery, Bar, Beer-to-go
# 4  Brewery, Bar, Beer-to-go
#
#                                    without_stopwords  \
# 0  10.24 batch. citra nose.. dankness well.. look...
# 1  This beer real treat. Lots sweet hop citrus no...
# 2  This wonderful offering MBC. While I'm huge fa...
# 3                               Amazing. That's word
# 4  Most likely best beer I ever had. Smell, look,...
#
#                                      lemmatized_text
# 0  batch citra nose dankness well look classic ha...
# 1  real treat lot sweet hop citrus note crisp dip...
# 2  wonderful offering mbc huge fan hype real hard...
# 3                                       amazing word
# 4          likely best ever smell look taste perfect

# %%
#no need for the "unnamed" column
beer = beer.drop(['Unnamed: 0'], axis=1)

# %%
#count the beer_id's, choose the most popular beers to be in the dataframe
beer['review_count'] = beer['beer_id'].groupby(beer['beer_id']).transform('count')

# %%
#sort the beers by number of reviews
pd.set_option('display.max_columns', None)
beer.sort_values(by=['review_count'], ascending=False)
# Out:
#          beer_id             username        date  \
# 44977      11757          wuthrichj15  2015-12-29
# 48010      11757               spoony  2014-12-28
# 48012      11757            hophugger  2014-11-12
# 48013      11757             Gregaroo  2014-12-03
# 48014      11757       infinitebruner  2014-11-28
# 48015      11757        RonaldTheriot  2014-12-11
# 48016      11757          ClavisAurea  2014-12-12
# 48017      11757            antonyliu  2018-09-29
# 48018      11757            dutesanch  2015-01-19
# 48019      11757          ranjitdighe  2015-01-22
# 48020      11757               71ADub  2015-01-02
# 48021      11757             DocCajun  2014-12-31
# 48022      11757               kudsak  2015-01-09
# 48023      11757            mschipper  2015-01-05
# 48024      11757    Nograinleftbehind  2018-03-25
# 48025      11757              Sigmund  2018-06-14
# 48026      11757              Peepskp  2016-04-15
# 48027      11757           Zythophile  2016-05-06
# 48028      11757         Thankin_Hank  2016-04-20
# 48029      11757             dfavreau  2016-04-29
# 48030      11757  SuperChugLosAngeles  2016-02-25
# 48031      11757              Pontzie  2016-09-11
# 48032      11757             kaseydad  2016-05-19
# 48033      11757              Shaun_S  2015-12-14
# 48034      11757               Sabtos  2015-12-21
# 48035      11757               KevCan  2015-12-17
# 48036      11757      The_Kriek_Freak  2015-12-20
# 48037      11757             RyanPoff  2015-11-10
# 48038      11757             dkanakis  2015-12-01
# 48039      11757               danh53  2015-11-25
# ...          ...                  ...         ...
# 1161065   266660       ron4ldm3xico76  2018-04-07
# 1161066   261495               heysuz  2016-12-28
# 1161163   126169          Texasfan549  2015-07-29
# 1161164   153294       OrestesMethuon  2015-01-15
# 1666553   225166            2beerdogs  2017-12-19
# 1160436   254728         Bouleboubier  2016-10-29
# 1160040   258234            dbl_delta  2017-04-10
# 1666574    64951             AdamBear  2011-01-01
# 1666661   332505               Sabtos  2018-03-15
# 1666658   332504               Sabtos  2018-03-22
# 1666657   332762               Sabtos  2018-03-15
# 1666656   332719               Sabtos  2018-03-22
# 1666655   332503               Sabtos  2018-03-22
# 1666654   272157               Sabtos  2017-03-27
# 1666653   264242               Sabtos  2018-03-22
# 1666645   314735               Sabtos  2018-03-22
# 1160056   332841               Sabtos  2018-03-13
# 1160057   259833             calcnerd  2016-12-14
# 1160058   188539                jzlyo  2016-10-27
# 1666626    54994           Hojaminbag  2009-12-25
# 1666625    65299            OWSLEY069  2011-01-14
# 1666624    50639           WVbeergeek  2009-06-22
# 1666617   186862                 Boto  2016-08-14
# 1160136   246625              Stooven  2017-03-16
# 1160137   277878              Rogerlb  2017-08-28
# 1160138   317249              Stooven  2018-09-28
# 1160139   293503       Hopheadjeffery  2017-07-26
# 1160406   116766              MacMalt  2017-01-15
# 1160426   101010                Curt3  2016-08-29
# 1698448    93450               Duff27  2013-05-10
#
#                                                       text  look  smell  \
# 44977    Just wow...what an absolutely fantastic beer. ...  5.00   5.00
# 48010    From a 355 ml bottle (bottled November 24, 201...  4.25   4.25
# 48012    Black, that is the color, 'nuff said. Head is ...  4.50   4.25
# 48013    10-16-16 - On tap at Moriarty's in Philly. Ser...  4.00   4.00
# 48014    November 22, 2014 12 oz bottle, snifter A – In...  4.00   4.50
# 48015    Founders Breakfast Stout has a thin, beige hea...  4.00   4.25
# 48016    Fresh 12oz bottle served in a snifter glass. B...  4.25   4.25
# 48017    12oz bottle poured into snifter glass --------...  4.50   4.00
# 48018    Very tasty, heavy coffee flavor with mild dark...  4.00   4.50
# 48019    Better than Guinness, but I prefer Sierra Neva...  5.00   5.00
# 48020    was well into my session when I had a bottle o...  4.00   4.25
# 48021    Lived up to expectations - very smooth, warm, ...  4.75   4.50
# 48022    Pretty good, very smooth. One of the best coff...  4.50   4.50
# 48023    A: Poured aggressively into a pint glass, give...  4.00   4.50
# 48024                                                 2017  4.25   4.50
# 48025    355 ml bottle, from Vinmonopolet Kvadrat. ABV ...  3.75   4.50
# 48026                   Great stout and readily available.  4.50   4.50
# 48027    Bottle Date: 11/13/15 Palate Contaminants: oth...  4.00   4.00
# 48028                                  Easy drinking beer.  4.50   4.00
# 48029    I enjoyed this beer ~2 weeks ago before I join...  4.50   4.25
# 48030    I am just not a fan of stouts that have heavy ...  4.50   4.25
# 48031    Hmmmmm ... I've had this before and don't reme...  4.25   4.25
# 48032    Dated 9/29/15 Happy to finally see Founders ma...  4.25   4.25
# 48033    I may need to try this one again I purchased a...  5.00   4.25
# 48034    Black with a thick, fluffy tan head. Big coffe...  4.50   4.00
# 48035    Bought a single 12 oz. bottle from Whole Foods...  4.50   4.00
# 48036    It pours dark and with a tan head. The head re...  4.25   4.00
# 48037    Bought a bottle of this famous stuff and poure...  3.75   4.75
# 48038    This year's batch has some additional metallic...  4.50   3.25
# 48039    On draft at bourbon county release. This was t...  4.25   3.50
# ...                                                    ...   ...    ...
# 1161065  Absolutely fantastic sour from Tin Man. Drank ...  3.75   4.25
# 1161066  This is a terrific beer. One of the most vanil...  4.00   4.75
# 1161163  Pours a black/dark brown with a light khaki he...  4.00   4.50
# 1161164  A nice, roundly-brown black, with a visible th...  4.50   3.75
# 1666553                                                 0%  3.75   3.50
# 1160436  (on-tap at the brewery tasting room, served in...  3.75   3.75
# 1160040  Draft at Stone Grille in York, PA. Pours a haz...  3.75   4.00
# 1666574  This is the beer Hofbrau will have if they've ...  3.50   3.50
# 1666661  Opaque sunset orange with a fuzzy bubbly colla...  3.25   3.75
# 1666658  Dark ruby-copper with a bubbly uneven collar. ...  3.75   4.25
# 1666657  Pale chill hazed salmon with a creamy light pi...  3.00   4.00
# 1666656  Ruby red with a fuzzy, thick persistent off-wh...  4.00   3.75
# 1666655  Glossy black with a thin mocha ring. Smell is ...  3.75   3.25
# 1666654  Beautiful bleeding beet red with a spongy, cra...  5.00   4.75
# 1666653  Foggy pale burnt peach-salmon with a thin bubb...  3.50   4.00
# 1666645  Appearance is hazy salmon with a fuzzy white-p...  3.50   3.00
# 1160056  Dark ruby with a creamy pink head leaving full...  4.25   2.75
# 1160057  Imperial Veggie Brown Ale. Eat your Veggies! (...  3.25   3.25
# 1160058  Aroma is citrus, wheat and a strong hint of la...  4.00   4.00
# 1666626  This is the December seasonal at Hofbräuhaus P...  4.00   3.00
# 1666625  Pours a clean orange-ish color with a white he...  3.50   3.50
# 1666624  I love a good German pils, this one was floode...  4.00   3.50
# 1666617  Draught @ Hofbrauhaus Pittsburgh: This one pou...  4.00   3.75
# 1160136  Death, taxes, ridiculous carbonation in Ten Ni...  3.50   4.25
# 1160137  From a bomber, pours black but not motor-oil b...  3.75   3.75
# 1160138  Rebranded "Juice God," (acquired from World-Wi...  3.25   4.00
# 1160139  Tasted in a Spiegelau IPA glass from a 12 oz b...  3.50   3.50
# 1160406  I had this on draught at the brewery. It was s...  3.75   3.75
# 1160426  Just ok. Not much of a smell and the color is ...  3.75   3.00
# 1698448  Very short lived white head, slim collar. Clou...  1.75   2.75
#
#          taste  feel  overall  score                         beer_name  \
# 44977     5.00  5.00     5.00   5.00                   Breakfast Stout
# 48010     4.50  3.75     4.25   4.30                   Breakfast Stout
# 48012     4.50  4.25     4.25   4.37                   Breakfast Stout
# 48013     4.25  4.25     4.25   4.18                   Breakfast Stout
# 48014     4.25  3.75     4.25   4.25                   Breakfast Stout
# 48015     4.25  4.00     4.25   4.21                   Breakfast Stout
# 48016     4.25  4.25     4.25   4.25                   Breakfast Stout
# 48017     3.75  4.25     4.25   4.01                   Breakfast Stout
# 48018     4.25  4.00     4.25   4.27                   Breakfast Stout
# 48019     4.00  3.25     4.25   4.28                   Breakfast Stout
# 48020     4.50  4.00     4.25   4.31                   Breakfast Stout
# 48021     4.25  4.25     4.25   4.34                   Breakfast Stout
# 48022     4.00  4.50     4.25   4.25                   Breakfast Stout
# 48023     4.25  4.25     4.25   4.30                   Breakfast Stout
# 48024     4.00  3.75     4.00   4.11                   Breakfast Stout
# 48025     4.00  4.00     4.00   4.11                   Breakfast Stout
# 48026     4.00  4.00     4.00   4.15                   Breakfast Stout
# 48027     4.00  4.25     4.00   4.03                   Breakfast Stout
# 48028     4.25  4.00     4.00   4.13                   Breakfast Stout
# 48029     3.75  4.50     4.00   4.04                   Breakfast Stout
# 48030     4.00  4.00     4.00   4.09                   Breakfast Stout
# 48031     3.75  4.50     4.00   4.03                   Breakfast Stout
# 48032     4.25  4.00     4.00   4.18                   Breakfast Stout
# 48033     3.50  4.00     4.00   3.92                   Breakfast Stout
# 48034     4.00  4.00     4.00   4.03                   Breakfast Stout
# 48035     4.00  4.00     4.00   4.03                   Breakfast Stout
# 48036     4.00  4.00     4.00   4.02                   Breakfast Stout
# 48037     4.00  3.75     4.00   4.14                   Breakfast Stout
# 48038     3.50  4.25     4.00   3.68                   Breakfast Stout
# 48039     4.00  4.25     4.00   3.92                   Breakfast Stout
# ...        ...   ...      ...    ...                               ...
# 1161065   4.50  3.75     4.25   4.27           WELD Cranberry Sour Ale
# 1161066   4.75  4.00     4.50   4.58  Bourbon Barrel Aged Vanilla Csar
# 1161163   4.50  3.75     4.25   4.35                    Whiskey Porter
# 1161164   3.25  3.00     3.25   3.42              Queen Anne's Revenge
# 1666553   3.50  3.50     3.50   3.52                   Californication
# 1160436   4.00  4.00     4.00   3.93                   Mooncusser Pils
# 1160040   3.50  3.75     3.75   3.71                       Mass Appeal
# 1666574   3.50  4.00     4.50   3.75               Hofbräu Zwickelbeer
# 1666661   4.00  4.00     4.00   3.90                  Do the Damn Tang
# 1666658   4.50  4.00     4.25   4.30                   It’s The Pleats
# 1666657   4.00  4.25     4.25   4.02                  Hidden Sprinkles
# 1666656   4.50  4.00     4.00   4.14                Magic Carpet Rye'd
# 1666655   4.00  3.75     4.00   3.78              Greater of Two Evils
# 1666654   4.50  4.50     4.50   4.59                   Disco Bloodbath
# 1666653   4.25  4.00     4.00   4.07                       Gypsy Tears
# 1666645   3.50  4.00     3.50   3.43                    Humpty Plumpty
# 1160056   3.00  3.50     3.00   3.07                   Cherry Hawbaker
# 1160057   3.25  3.25     3.25   3.25                 Don't Carrot All!
# 1160058   4.25  4.25     4.25   4.18                         Sharp Wit
# 1666626   3.00  3.00     3.00   3.06             Hofbräu Christmasbeer
# 1666625   3.50  3.50     3.50   3.50                 Hofbräu Berg Bock
# 1666624   3.00  3.00     3.50   3.28            Hofbräu German Pilsner
# 1666617   4.00  4.00     4.00   3.94                     Sommer Weizen
# 1160136   4.25  3.25     3.75   4.01                 72 Hour Work Week
# 1160137   4.00  4.25     4.00   3.95                               MPH
# 1160138   3.75  3.50     3.50   3.71                          Masshole
# 1160139   3.50  3.50     3.50   3.50               90 Feet From Heaven
# 1160406   4.00  4.00     4.00   3.93                      Tripel Wreck
# 1160426   3.25  3.50     3.50   3.30                  Watermelon Wheat
# 1698448   2.25  1.50     1.75   2.17                        Golden Ale
#
#          brewery_id state country                            style  \
# 44977          1199    MI      US          American Imperial Stout
# 48010          1199    MI      US          American Imperial Stout
# 48012          1199    MI      US          American Imperial Stout
# 48013          1199    MI      US          American Imperial Stout
# 48014          1199    MI      US          American Imperial Stout
# 48015          1199    MI      US          American Imperial Stout
# 48016          1199    MI      US          American Imperial Stout
# 48017          1199    MI      US          American Imperial Stout
# 48018          1199    MI      US          American Imperial Stout
# 48019          1199    MI      US          American Imperial Stout
# 48020          1199    MI      US          American Imperial Stout
# 48021          1199    MI      US          American Imperial Stout
# 48022          1199    MI      US          American Imperial Stout
# 48023          1199    MI      US          American Imperial Stout
# 48024          1199    MI      US          American Imperial Stout
# 48025          1199    MI      US          American Imperial Stout
# 48026          1199    MI      US          American Imperial Stout
# 48027          1199    MI      US          American Imperial Stout
# 48028          1199    MI      US          American Imperial Stout
# 48029          1199    MI      US          American Imperial Stout
# 48030          1199    MI      US          American Imperial Stout
# 48031          1199    MI      US          American Imperial Stout
# 48032          1199    MI      US          American Imperial Stout
# 48033          1199    MI      US          American Imperial Stout
# 48034          1199    MI      US          American Imperial Stout
# 48035          1199    MI      US          American Imperial Stout
# 48036          1199    MI      US          American Imperial Stout
# 48037          1199    MI      US          American Imperial Stout
# 48038          1199    MI      US          American Imperial Stout
# 48039          1199    MI      US          American Imperial Stout
# ...             ...   ...     ...                              ...
# 1161065       28567    IN      US                American Wild Ale
# 1161066       28567    IN      US           Russian Imperial Stout
# 1161163       24447    FL      US                  American Porter
# 1161164       24447    FL      US                   American Stout
# 1666553       33817    CA      US                    German Kölsch
# 1160436       25890    NJ      US                Bohemian Pilsener
# 1160040       18316    PA      US              American Blonde Ale
# 1666574       19587    PA      US  German Kellerbier / Zwickelbier
# 1666661       46941    FL      US                     American IPA
# 1666658       46941    FL      US                American Wild Ale
# 1666657       46941    FL      US                American Wild Ale
# 1666656       46941    FL      US                     Leipzig Gose
# 1666655       46941    FL      US          American Imperial Stout
# 1666654       46941    FL      US                   Belgian Saison
# 1666653       46941    FL      US                  Berliner Weisse
# 1666645       46941    FL      US                  Berliner Weisse
# 1160056       18316    PA      US            American Imperial IPA
# 1160057       18316    PA      US               American Brown Ale
# 1160058       31783    IL      US                American Wild Ale
# 1666626       19587    PA      US                     Vienna Lager
# 1666625       19587    PA      US                   German Altbier
# 1666624       19587    PA      US                   German Pilsner
# 1666617       19587    PA      US                German Hefeweizen
# 1160136       31783    IL      US            American Imperial IPA
# 1160137       31783    IL      US                  American Porter
# 1160138       31783    IL      US                     American IPA
# 1160139       31783    IL      US                     American IPA
# 1160406       25890    NJ      US                   Belgian Tripel
# 1160426       25890    NJ      US          American Pale Wheat Ale
# 1698448       30406    OR      US          Belgian Strong Pale Ale
#
#                    availability    abv  \
# 44977                  Rotating   8.30
# 48010                  Rotating   8.30
# 48012                  Rotating   8.30
# 48013                  Rotating   8.30
# 48014                  Rotating   8.30
# 48015                  Rotating   8.30
# 48016                  Rotating   8.30
# 48017                  Rotating   8.30
# 48018                  Rotating   8.30
# 48019                  Rotating   8.30
# 48020                  Rotating   8.30
# 48021                  Rotating   8.30
# 48022                  Rotating   8.30
# 48023                  Rotating   8.30
# 48024                  Rotating   8.30
# 48025                  Rotating   8.30
# 48026                  Rotating   8.30
# 48027                  Rotating   8.30
# 48028                  Rotating   8.30
# 48029                  Rotating   8.30
# 48030                  Rotating   8.30
# 48031                  Rotating   8.30
# 48032                  Rotating   8.30
# 48033                  Rotating   8.30
# 48034                  Rotating   8.30
# 48035                  Rotating   8.30
# 48036                  Rotating   8.30
# 48037                  Rotating   8.30
# 48038                  Rotating   8.30
# 48039                  Rotating   8.30
# ...                         ...    ...
# 1161065                  Winter   5.20
# 1161066                Rotating  12.00
# 1161163                Rotating   8.50
# 1161164              Year-round    NaN
# 1666553                Rotating   5.20
# 1160436                Rotating   5.20
# 1160040                Rotating   4.70
# 1666574                Rotating   5.20
# 1666661   Limited (brewed once)   6.50
# 1666658   Limited (brewed once)   9.00
# 1666657   Limited (brewed once)   5.50
# 1666656                Rotating   4.10
# 1666655   Limited (brewed once)  11.00
# 1666654                Rotating   5.40
# 1666653                Rotating   3.40
# 1666645                Rotating   3.70
# 1160056   Limited (brewed once)   7.40
# 1160057                Rotating   9.20
# 1160058                Rotating   4.30
# 1666626                Rotating   5.50
# 1666625                  Winter   6.80
# 1666624                  Summer   5.00
# 1666617                  Summer   5.60
# 1160136                Rotating  10.00
# 1160137                  Winter  10.80
# 1160138                Rotating   6.79
# 1160139                Rotating   6.30
# 1160406                Rotating  10.30
# 1160426                Rotating   5.50
# 1698448              Year-round   9.20
#
#                                                 beer_notes retired  \
# 44977                              Availability: Sep - Dec       f
# 48010                              Availability: Sep - Dec       f
# 48012                              Availability: Sep - Dec       f
# 48013                              Availability: Sep - Dec       f
# 48014                              Availability: Sep - Dec       f
# 48015                              Availability: Sep - Dec       f
# 48016                              Availability: Sep - Dec       f
# 48017                              Availability: Sep - Dec       f
# 48018                              Availability: Sep - Dec       f
# 48019                              Availability: Sep - Dec       f
# 48020                              Availability: Sep - Dec       f
# 48021                              Availability: Sep - Dec       f
# 48022                              Availability: Sep - Dec       f
# 48023                              Availability: Sep - Dec       f
# 48024                              Availability: Sep - Dec       f
# 48025                              Availability: Sep - Dec       f
# 48026                              Availability: Sep - Dec       f
# 48027                              Availability: Sep - Dec       f
# 48028                              Availability: Sep - Dec       f
# 48029                              Availability: Sep - Dec       f
# 48030                              Availability: Sep - Dec       f
# 48031                              Availability: Sep - Dec       f
# 48032                              Availability: Sep - Dec       f
# 48033                              Availability: Sep - Dec       f
# 48034                              Availability: Sep - Dec       f
# 48035                              Availability: Sep - Dec       f
# 48036                              Availability: Sep - Dec       f
# 48037                              Availability: Sep - Dec       f
# 48038                              Availability: Sep - Dec       f
# 48039                              Availability: Sep - Dec       f
# ...                                                    ...     ...
# 1161065  A crisp and tart Kettle-Soured Ale with cranberry       f
# 1161066                             No notes at this time.       f
# 1161163                             No notes at this time.       f
# 1161164                             No notes at this time.       f
# 1666553                             No notes at this time.       f
# 1160436                             No notes at this time.       f
# 1160040                             No notes at this time.       f
# 1666574                             No notes at this time.       f
# 1666661                             No notes at this time.       f
# 1666658                             No notes at this time.       f
# 1666657                             No notes at this time.       f
# 1666656                               Boysenberry Rye Sour       f
# 1666655                             No notes at this time.       f
# 1666654                          Black currant dark saison       f
# 1666653                             No notes at this time.       f
# 1666645                             No notes at this time.       f
# 1160056                             No notes at this time.       f
# 1160057                             No notes at this time.       f
# 1160058                             No notes at this time.       f
# 1666626                             No notes at this time.       f
# 1666625                             No notes at this time.       f
# 1666624                             No notes at this time.       f
# 1666617  A darker, maltier version of the Weizen bier w...       f
# 1160136                             No notes at this time.       f
# 1160137                             No notes at this time.       f
# 1160138                             No notes at this time.       f
# 1160139                             No notes at this time.       f
# 1160406  This traditional belgian triple is light in bo...       f
# 1160426  This wheat beer is steeped with 500 lbs of fre...       f
# 1698448                             No notes at this time.       f
#
#                                 brewery_name              city  \
# 44977               Founders Brewing Company      Grand Rapids
# 48010               Founders Brewing Company      Grand Rapids
# 48012               Founders Brewing Company      Grand Rapids
# 48013               Founders Brewing Company      Grand Rapids
# 48014               Founders Brewing Company      Grand Rapids
# 48015               Founders Brewing Company      Grand Rapids
# 48016               Founders Brewing Company      Grand Rapids
# 48017               Founders Brewing Company      Grand Rapids
# 48018               Founders Brewing Company      Grand Rapids
# 48019               Founders Brewing Company      Grand Rapids
# 48020               Founders Brewing Company      Grand Rapids
# 48021               Founders Brewing Company      Grand Rapids
# 48022               Founders Brewing Company      Grand Rapids
# 48023               Founders Brewing Company      Grand Rapids
# 48024               Founders Brewing Company      Grand Rapids
# 48025               Founders Brewing Company      Grand Rapids
# 48026               Founders Brewing Company      Grand Rapids
# 48027               Founders Brewing Company      Grand Rapids
# 48028               Founders Brewing Company      Grand Rapids
# 48029               Founders Brewing Company      Grand Rapids
# 48030               Founders Brewing Company      Grand Rapids
# 48031               Founders Brewing Company      Grand Rapids
# 48032               Founders Brewing Company      Grand Rapids
# 48033               Founders Brewing Company      Grand Rapids
# 48034               Founders Brewing Company      Grand Rapids
# 48035               Founders Brewing Company      Grand Rapids
# 48036               Founders Brewing Company      Grand Rapids
# 48037               Founders Brewing Company      Grand Rapids
# 48038               Founders Brewing Company      Grand Rapids
# 48039               Founders Brewing Company      Grand Rapids
# ...                                      ...               ...
# 1161065              Tin Man Brewing Company        Evansville
# 1161066              Tin Man Brewing Company        Evansville
# 1161163                Pensacola Bay Brewery         Pensacola
# 1161164                Pensacola Bay Brewery         Pensacola
# 1666553                Hoparazzi Brewing Co.           Anaheim
# 1160436             Cape May Brewing Company          Cape May
# 1160040  Al's of Hampden / Pizza Boy Brewing             Enola
# 1666574               Hofbräuhaus Pittsburgh        Pittsburgh
# 1666661                      Arkane Aleworks             Largo
# 1666658                      Arkane Aleworks             Largo
# 1666657                      Arkane Aleworks             Largo
# 1666656                      Arkane Aleworks             Largo
# 1666655                      Arkane Aleworks             Largo
# 1666654                      Arkane Aleworks             Largo
# 1666653                      Arkane Aleworks             Largo
# 1666645                      Arkane Aleworks             Largo
# 1160056  Al's of Hampden / Pizza Boy Brewing             Enola
# 1160057  Al's of Hampden / Pizza Boy Brewing             Enola
# 1160058           Ten Ninety Brewing Company          Glenview
# 1666626               Hofbräuhaus Pittsburgh        Pittsburgh
# 1666625               Hofbräuhaus Pittsburgh        Pittsburgh
# 1666624               Hofbräuhaus Pittsburgh        Pittsburgh
# 1666617               Hofbräuhaus Pittsburgh        Pittsburgh
# 1160136           Ten Ninety Brewing Company          Glenview
# 1160137           Ten Ninety Brewing Company          Glenview
# 1160138           Ten Ninety Brewing Company          Glenview
# 1160139           Ten Ninety Brewing Company          Glenview
# 1160406             Cape May Brewing Company          Cape May
# 1160426             Cape May Brewing Company          Cape May
# 1698448                Dragon's Gate Brewery  Milton Freewater
#
#                                              brewery_notes  \
# 44977    Mahou San Miguel has a 30% ownership stake sin...
# 48010    Mahou San Miguel has a 30% ownership stake sin...
# 48012    Mahou San Miguel has a 30% ownership stake sin...
# 48013    Mahou San Miguel has a 30% ownership stake sin...
# 48014    Mahou San Miguel has a 30% ownership stake sin...
# 48015    Mahou San Miguel has a 30% ownership stake sin...
# 48016    Mahou San Miguel has a 30% ownership stake sin...
# 48017    Mahou San Miguel has a 30% ownership stake sin...
# 48018    Mahou San Miguel has a 30% ownership stake sin...
# 48019    Mahou San Miguel has a 30% ownership stake sin...
# 48020    Mahou San Miguel has a 30% ownership stake sin...
# 48021    Mahou San Miguel has a 30% ownership stake sin...
# 48022    Mahou San Miguel has a 30% ownership stake sin...
# 48023    Mahou San Miguel has a 30% ownership stake sin...
# 48024    Mahou San Miguel has a 30% ownership stake sin...
# 48025    Mahou San Miguel has a 30% ownership stake sin...
# 48026    Mahou San Miguel has a 30% ownership stake sin...
# 48027    Mahou San Miguel has a 30% ownership stake sin...
# 48028    Mahou San Miguel has a 30% ownership stake sin...
# 48029    Mahou San Miguel has a 30% ownership stake sin...
# 48030    Mahou San Miguel has a 30% ownership stake sin...
# 48031    Mahou San Miguel has a 30% ownership stake sin...
# 48032    Mahou San Miguel has a 30% ownership stake sin...
# 48033    Mahou San Miguel has a 30% ownership stake sin...
# 48034    Mahou San Miguel has a 30% ownership stake sin...
# 48035    Mahou San Miguel has a 30% ownership stake sin...
# 48036    Mahou San Miguel has a 30% ownership stake sin...
# 48037    Mahou San Miguel has a 30% ownership stake sin...
# 48038    Mahou San Miguel has a 30% ownership stake sin...
# 48039    Mahou San Miguel has a 30% ownership stake sin...
# ...                                                    ...
# 1161065  Brewery only now. All growler fill, food servi...
# 1161066  Brewery only now. All growler fill, food servi...
# 1161163                             No notes at this time.
# 1161164                             No notes at this time.
# 1666553      Tasting room scheduled to open in early 2014.
# 1160436  Our Tasting Room and Brewtique are open daily ...
# 1160040                                             Hours:
# 1666574                                   Opens Daily 11am
# 1666661                             No notes at this time.
# 1666658                             No notes at this time.
# 1666657                             No notes at this time.
# 1666656                             No notes at this time.
# 1666655                             No notes at this time.
# 1666654                             No notes at this time.
# 1666653                             No notes at this time.
# 1666645                             No notes at this time.
# 1160056                                             Hours:
# 1160057                                             Hours:
# 1160058                             No notes at this time.
# 1666626                                   Opens Daily 11am
# 1666625                                   Opens Daily 11am
# 1666624                                   Opens Daily 11am
# 1666617                                   Opens Daily 11am
# 1160136                             No notes at this time.
# 1160137                             No notes at this time.
# 1160138                             No notes at this time.
# 1160139                             No notes at this time.
# 1160406  Our Tasting Room and Brewtique are open daily ...
# 1160426  Our Tasting Room and Brewtique are open daily ...
# 1698448                             No notes at this time.
#
#                                     types  \
# 44977    Brewery, Bar, Eatery, Beer-to-go
# 48010    Brewery, Bar, Eatery, Beer-to-go
# 48012    Brewery, Bar, Eatery, Beer-to-go
# 48013    Brewery, Bar, Eatery, Beer-to-go
# 48014    Brewery, Bar, Eatery, Beer-to-go
# 48015    Brewery, Bar, Eatery, Beer-to-go
# 48016    Brewery, Bar, Eatery, Beer-to-go
# 48017    Brewery, Bar, Eatery, Beer-to-go
# 48018    Brewery, Bar, Eatery, Beer-to-go
# 48019    Brewery, Bar, Eatery, Beer-to-go
# 48020    Brewery, Bar, Eatery, Beer-to-go
# 48021    Brewery, Bar, Eatery, Beer-to-go
# 48022    Brewery, Bar, Eatery, Beer-to-go
# 48023    Brewery, Bar, Eatery, Beer-to-go
# 48024    Brewery, Bar, Eatery, Beer-to-go
# 48025    Brewery, Bar, Eatery, Beer-to-go
# 48026    Brewery, Bar, Eatery, Beer-to-go
# 48027    Brewery, Bar, Eatery, Beer-to-go
# 48028    Brewery, Bar, Eatery, Beer-to-go
# 48029    Brewery, Bar, Eatery, Beer-to-go
# 48030    Brewery, Bar, Eatery, Beer-to-go
# 48031    Brewery, Bar, Eatery, Beer-to-go
# 48032    Brewery, Bar, Eatery, Beer-to-go
# 48033    Brewery, Bar, Eatery, Beer-to-go
# 48034    Brewery, Bar, Eatery, Beer-to-go
# 48035    Brewery, Bar, Eatery, Beer-to-go
# 48036    Brewery, Bar, Eatery, Beer-to-go
# 48037    Brewery, Bar, Eatery, Beer-to-go
# 48038    Brewery, Bar, Eatery, Beer-to-go
# 48039    Brewery, Bar, Eatery, Beer-to-go
# ...                                   ...
# 1161065                           Brewery
# 1161066                           Brewery
# 1161163          Brewery, Bar, Beer-to-go
# 1161164          Brewery, Bar, Beer-to-go
# 1666553          Brewery, Bar, Beer-to-go
# 1160436          Brewery, Bar, Beer-to-go
# 1160040  Brewery, Bar, Eatery, Beer-to-go
# 1666574              Brewery, Bar, Eatery
# 1666661          Brewery, Bar, Beer-to-go
# 1666658          Brewery, Bar, Beer-to-go
# 1666657          Brewery, Bar, Beer-to-go
# 1666656          Brewery, Bar, Beer-to-go
# 1666655          Brewery, Bar, Beer-to-go
# 1666654          Brewery, Bar, Beer-to-go
# 1666653          Brewery, Bar, Beer-to-go
# 1666645          Brewery, Bar, Beer-to-go
# 1160056  Brewery, Bar, Eatery, Beer-to-go
# 1160057  Brewery, Bar, Eatery, Beer-to-go
# 1160058                      Brewery, Bar
# 1666626              Brewery, Bar, Eatery
# 1666625              Brewery, Bar, Eatery
# 1666624              Brewery, Bar, Eatery
# 1666617              Brewery, Bar, Eatery
# 1160136                      Brewery, Bar
# 1160137                      Brewery, Bar
# 1160138                      Brewery, Bar
# 1160139                      Brewery, Bar
# 1160406          Brewery, Bar, Beer-to-go
# 1160426          Brewery, Bar, Beer-to-go
# 1698448          Brewery, Bar, Beer-to-go
#
#                                          without_stopwords  \
# 44977    Just wow...what absolutely fantastic beer. Cho...
# 48010    From 355 ml bottle (bottled November 24, 2014)...
# 48012    Black, color, 'nuff said. Head white/coffee co...
# 48013    10-16-16 - On tap Moriarty's Philly. Served da...
# 48014    November 22, 2014 12 oz bottle, snifter A – In...
# 48015    Founders Breakfast Stout thin, beige head, dar...
# 48016    Fresh 12oz bottle served snifter glass. Bottle...
# 48017    12oz bottle poured snifter glass ---------- Lo...
# 48018    Very tasty, heavy coffee flavor mild dark choc...
# 48019    Better Guinness, I prefer Sierra Nevada Stout....
# 48020    well session I bottle stuff...so i'll follow K...
# 48021    Lived expectations - smooth, warm, comforting....
# 48022    Pretty good, smooth. One best coffee type stou...
# 48023    A: Poured aggressively pint glass, gives finge...
# 48024                                                 2017
# 48025    355 ml bottle, Vinmonopolet Kvadrat. ABV 8.3%,...
# 48026                       Great stout readily available.
# 48027    Bottle Date: 11/13/15 Palate Contaminants: bee...
# 48028                                  Easy drinking beer.
# 48029    I enjoyed beer ~2 weeks ago I joined BA. I pre...
# 48030    I fan stouts heavy coffee flavor. I like coffe...
# 48031    Hmmmmm ... I've remember overwhelmingly flavor...
# 48032    Dated 9/29/15 Happy finally see Founders make ...
# 48033    I may need try one I purchased 4 pack October ...
# 48034    Black thick, fluffy tan head. Big coffee choco...
# 48035    Bought single 12 oz. bottle Whole Foods Arling...
# 48036    It pours dark tan head. The head retention gre...
# 48037    Bought bottle famous stuff poured pint glass h...
# 48038    This year's batch additional metallic taste/sm...
# 48039    On draft bourbon county release. This pregame ...
# ...                                                    ...
# 1161065  Absolutely fantastic sour Tin Man. Drank pint ...
# 1161066  This terrific beer. One vanilla forward stouts...
# 1161163  Pours black/dark brown light khaki head. A lit...
# 1161164  A nice, roundly-brown black, visible thickness...
# 1666553                                                 0%
# 1160436  (on-tap brewery tasting room, served shaker pi...
# 1160040  Draft Stone Grille York, PA. Pours hazy straw ...
# 1666574  This beer Hofbrau they've emptied one seasonal...
# 1666661  Opaque sunset orange fuzzy bubbly collar. Smel...
# 1666658  Dark ruby-copper bubbly uneven collar. Smell s...
# 1666657  Pale chill hazed salmon creamy light pink ring...
# 1666656  Ruby red fuzzy, thick persistent off-white pin...
# 1666655  Glossy black thin mocha ring. Smell nutty coco...
# 1666654  Beautiful bleeding beet red spongy, crazy thic...
# 1666653  Foggy pale burnt peach-salmon thin bubbly coll...
# 1666645  Appearance hazy salmon fuzzy white-pink blanke...
# 1160056  Dark ruby creamy pink head leaving full sheet ...
# 1160057  Imperial Veggie Brown Ale. Eat Veggies! (500 l...
# 1160058  Aroma citrus, wheat strong hint lactic acid. T...
# 1666626  This December seasonal Hofbräuhaus Pittsburgh....
# 1666625  Pours clean orange-ish color white head. In ar...
# 1666624  I love good German pils, one flooded pelletize...
# 1666617  Draught @ Hofbrauhaus Pittsburgh: This one pou...
# 1160136  Death, taxes, ridiculous carbonation Ten Ninet...
# 1160137  From bomber, pours black motor-oil black. A sl...
# 1160138  Rebranded "Juice God," (acquired World-Wide li...
# 1160139  Tasted Spiegelau IPA glass 12 oz bottle July 2...
# 1160406  I draught brewery. It served pint glass. It po...
# 1160426  Just ok. Not much smell color pleasing. The wa...
# 1698448  Very short lived white head, slim collar. Clou...
#
#                                            lemmatized_text  review_count
# 44977    wow absolutely fantastic chocolate coffee flav...          4167
# 48010    ml bottle bottled november wine glass thin bro...          4167
# 48012    black color nuff said head white coffee colore...          4167
# 48013    tap moriarty philly served dark almost black c...          4167
# 48014    november bottle snifter ink black light brown ...          4167
# 48015    founder breakfast stout thin beige head dark b...          4167
# 48016    fresh bottle served snifter glass bottle dated...          4167
# 48017    bottle poured snifter glass look like pour cof...          4167
# 48018    tasty heavy coffee flavor mild dark chocolate ...          4167
# 48019    better guinness prefer sierra nevada stout nic...          4167
# 48020    well session bottle stuff follow kiss method b...          4167
# 48021    lived expectation smooth warm comforting refri...          4167
# 48022    pretty good smooth best coffee type stout hint...          4167
# 48023    poured aggressively pint glass give finger hal...          4167
# 48024                                                  NaN          4167
# 48025    ml bottle vinmonopolet kvadrat abv ibu pitch b...          4167
# 48026                        great stout readily available          4167
# 48027    bottle date palate contaminant appearance let ...          4167
# 48028                                        easy drinking          4167
# 48029    enjoyed week ago joined ba prefer light sweete...          4167
# 48030    fan stout heavy coffee flavor like coffee flav...          4167
# 48031    hmmmmm remember overwhelmingly flavored liked ...          4167
# 48032    dated happy finally see founder make way cali ...          4167
# 48033    may need try purchased pack october batch desp...          4167
# 48034    black thick fluffy tan head big coffee chocola...          4167
# 48035    bought single bottle whole food arlington va b...          4167
# 48036    pours dark tan head head retention great aroma...          4167
# 48037    bought bottle famous stuff poured pint glass h...          4167
# 48038    year batch additional metallic taste smell att...          4167
# 48039    draft bourbon county release pregame warm pour...          4167
# ...                                                    ...           ...
# 1161065  absolutely fantastic sour tin man drank pint t...             1
# 1161066  terrific vanilla forward stout encountered tri...             1
# 1161163  pours black dark brown light khaki head little...             1
# 1161164  nice roundly brown black visible thickness nos...             1
# 1666553                                                NaN             1
# 1160436  tap brewery tasting room served shaker pint ap...             1
# 1160040  draft stone grille york pa pours hazy straw co...             1
# 1666574  hofbrau emptied seasonal quite ready start new...             1
# 1666661  opaque sunset orange fuzzy bubbly collar smell...             1
# 1666658  dark ruby copper bubbly uneven collar smell sp...             1
# 1666657  pale chill hazed salmon creamy light pink ring...             1
# 1666656  ruby red fuzzy thick persistent white pink bub...             1
# 1666655  glossy black thin mocha ring smell nutty cocoa...             1
# 1666654  beautiful bleeding beet red spongy crazy thick...             1
# 1666653  foggy pale burnt peach salmon thin bubbly coll...             1
# 1666645  appearance hazy salmon fuzzy white pink blanke...             1
# 1160056  dark ruby creamy pink head leaving full sheet ...             1
# 1160057  imperial veggie brown ale eat veggie lb carrot...             1
# 1160058  aroma citrus wheat strong hint lactic acid fla...             1
# 1666626  december seasonal hofbräuhaus pittsburgh put v...             1
# 1666625  pours clean orange ish color white head aroma ...             1
# 1666624  love good german pils flooded pelletized hop f...             1
# 1666617  draught hofbrauhaus pittsburgh pours cloudy da...             1
# 1160136  death tax ridiculous carbonation ten ninety fr...             1
# 1160137  bomber pours black motor oil black slight brow...             1
# 1160138  rebranded juice god acquired world wide liquor...             1
# 1160139  tasted spiegelau ipa glass bottle july look br...             1
# 1160406  draught brewery served pint glass pours amber ...             1
# 1160426  ok much smell color pleasing watermelon finish...             1
# 1698448  short lived white head slim collar cloudy appl...             1
#
# [1698449 rows x 26 columns]

# %%
#histogram plot of beer reviews per beer
beer['review_count'].hist()

# %% [markdown]
# The above histogram is telling us that most beers have under 1000 reviews and in the rare case have 4000+ reviews.

# %%
#how many unique beers will there be in the dataset when we cut off the threshold at 200 reviews?
beer_200 = beer[beer.review_count >= 200]

# %%
#get beer_200 info and find how many unique beers there are
beer_200['beer_id'].nunique()
# Out:
# 1630

# %% [markdown]
# If a beer hasn't been reviewed at least 200 times, it will be dropped. This results in 1600+ unique beers made in the USA.

# %%
#visualize the amount of beers reviewed per style represented in the dataset

plt.figure(figsize=(15,20))
overall = beer_200.groupby('style')['beer_id'].count().sort_values(ascending=True).plot(kind='barh', title='Beers Reviewed per Style')
overall.set_xlabel('Beer Count')
overall.set_ylabel('Beer Style')
plt.show()

# %% [markdown]
# As we can see from the graph, the American IPA dominates the beers reviewed in the USA. This is not surprising as it is the most popular craft beer style. Brewers actually have a saying, "IPA's pay the bills." And it's true, consumers demand a high quality IPA because they're so well liked among the general population. Brewers, however, typically don't like brewing these styles as they can be a pain to brew with all the hop additions needed to achieve the proper flavor.

# %%
beer_200.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# As we can see, as before with all countries and reviews, reviewers tend to leave reviews when they feel the beer is good. Most beers land in the 4 range out of a possible score of 5.

# %% [markdown]
# ## Content Recommender

# %% [markdown]
# Now that we have done some data analysis, we can start building the pieces of the recommender. First, we'll build the content recommender which will analyze the text reviews and recommend beers from the reviews.

# %%
#create new dataframe
beer_200_text = beer_200[['beer_id', 'beer_name', 'brewery_name', 'lemmatized_text']]

# %%
#drop null values
beer_200_text = beer_200_text.dropna(axis=0, subset=['lemmatized_text'])

# %%
#group by beer
grouped_text = beer_200_text.groupby(['beer_id', 'brewery_name', 'beer_name'])['lemmatized_text'].agg(lambda col: ''.join(col))

#df
beer_200_text = pd.DataFrame(grouped_text)
beer_200_text = beer_200_text.reset_index()
beer_200_text.head()
# Out:
#    beer_id                     brewery_name          beer_name  \
# 0        5                Abita Brewing Co.              Amber
# 1        6                Abita Brewing Co.           Turbodog
# 2        7                Abita Brewing Co.        Purple Haze
# 3       10         Allagash Brewing Company         Dubbel Ale
# 4       17  Widmer Brothers Brewing Company  Widmer Hefeweizen
#
#                                      lemmatized_text
# 0  becoming favorite mine pours dark golden color...
# 1  fan dark flavorful ale met mark well started c...
# 2  purple virtually head second finger head dissi...
# 3  brown ml bottle corked caged batch bottled acc...
# 4  american style hefe taste delicious every time...

# %%
beer_200_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 4 columns):
# beer_id            1630 non-null int64
# brewery_name       1630 non-null object
# beer_name          1630 non-null object
# lemmatized_text    1630 non-null object
# dtypes: int64(1), object(3)
# memory usage: 51.0+ KB

# %%
beer_200_text = pd.read_csv(r'F:\Datasets\beer_200_text.csv')

# %%
#using lemmatized_text, create the corpus
corpus = beer_200_text['lemmatized_text']
corpus
# Out:
# 0       becoming favorite mine pours dark golden color...
# 1       fan dark flavorful ale met mark well started c...
# 2       purple virtually head second finger head dissi...
# 3       brown ml bottle corked caged batch bottled acc...
# 4       american style hefe taste delicious every time...
# 5       well balanced pale ale market made go food pai...
# 6       pours nearly pitch black color dark chocolatey...
# 7       nice sized head really beautiful lacing dark q...
# 8       pours hazy brown orange medium thick white hea...
# 9       tasted appearance pale hazy gold thin head qui...
# 10      great blask smoothdark brown almost black body...
# 11      appearance amber color clear lot fine bubble r...
# 12      bad representation budweiser always found kill...
# 13      good malt liquor cheaper areaokay know alot pe...
# 14      nothing ordinary usual blonde ale seems pushed...
# 15      ginger vanilla allspice pumpkin smell taste pr...
# 16      note like strong coffee like porter enjoy idea...
# 17      dark pour black brown around edge held light t...
# 18      poor bottle nice frothy poor nice finger froth...
# 19      sh sh realsies im super cereal favorite ipa go...
# 20      almost completely opaque light brown head comp...
# 21      liked much got appropriate glassware stone bre...
# 22      appearance gt hazy light carbonation head laci...
# 23      bottle poured sprecher stemmed pokal abv schwa...
# 24      big fan pumpkin aleblue moon harvest moon pump...
# 25      perfect brew season tiz season winter ale anyw...
# 26      everything desire perfect manygreat marzen lov...
# 27      w freshness date app golden amber slight haze ...
# 28      preamble world finest disconcerting rarely rec...
# 29      pours hazy wheat color hint orange even slight...
#                               ...
# 1600    pours pitch black creamy tan head ha strong ar...
# 1601    absolutely love top favoritebloody phenomenal ...
# 1602    tap point athens ga pint growler fill l beauti...
# 1603    poured pint glass winter seasonal pack general...
# 1604    love fresh bright citrus ipalike citrus ipa li...
# 1605    pours deep red ruby color thick head good look...
# 1606    wow brewed serious bean say lo although din no...
# 1607    look dark orange cloudy heck lot floaties big ...
# 1608    sour smell fruit taste bitter enough make drin...
# 1609    new favorite turned people onto since thanksgi...
# 1610    make way melon passion fruit pulling apricot d...
# 1611    say make everyday cheap bud coors exactly want...
# 1612    nice golden completely clear color first becam...
# 1613    great dessert taste burnt caramel smell burnt ...
# 1614    bottle stamped presumably mean bottled beauty ...
# 1615    look pours vibrant hazy orange glow finger egg...
# 1616    super tasty reasonably pricedwa really looking...
# 1617    good pale ale good price born yesterday liteim...
# 1618    sweet citrus nice chocolate note background ta...
# 1619    tap poured oversized wine glass look pitch bla...
# 1620    another amazing dogfish highly innovative drin...
# 1621    magnum pale ale originator craft brewing movem...
# 1622    perfect companion complement torpedo well bala...
# 1623    purchased poured fresh f clean spiegelau tulip...
# 1624    mmm goodtropical ipa transport hop induced sta...
# 1625    straight joos good many trillium offeringbest ...
# 1626    introduction looking forward since year sierra...
# 1627    great taste lovepoured snifter bottle deep gol...
# 1628    tasty well balanced ipa nice finish two curren...
# 1629    low deserves wtflook opaque unfiltered orange ...
# Name: lemmatized_text, Length: 1630, dtype: object

# %% [markdown]
# ## Bag of Words

# %%
bag_of_words_model = CountVectorizer(max_features=100)
bag_of_words_model.fit_transform(corpus)
# Out:
# <1630x100 sparse matrix of type '<class 'numpy.int64'>'
# 	with 160012 stored elements in Compressed Sparse Row format>

# %%
bag_of_word_df = pd.DataFrame(bag_of_words_model.fit_transform(corpus).todense())
bag_of_word_df.columns = sorted(bag_of_words_model.vocabulary_)
bag_of_word_df.head()
# Out:
#    alcohol  ale  almost  amber  aroma  balance  balanced  big  bit  bitter  \
# 0       20   46      61    532    272       39        46   30  199      40
# 1       74  490     204     86    455      105        96   62  477     224
# 2       29   43     126    119    338       50        47   52  279      32
# 3      266  116     112    187    413       75        73   87  372     110
# 4       22  115     133     47    342       38        35   59  307     105
#
#    bitterness  black  bodied  body  bottle  brew  brown  caramel  carbonation  \
# 0          96      2      92   163     126   115     67      405          224
# 1         221    152     162   317     241   234   1467      435          401
# 2          63      3      93   200     201   172     37       12          330
# 3         107     24     133   237     271   171    598      270          372
# 4          94      3      99   205     197   116     26       21          299
#
#    chocolate  citrus  clear  coffee  color  creamy  dark  decent  definitely  \
# 0          9      36    148       8    282      50    56      97          22
# 1        875      15     85     431    329     187   874     186          95
# 2          1      50     34       0    397      39    38     137          81
# 3        191      39     41     103    301     159   636      94          61
# 4          1     450     17       0    317      85    34     191          58
#
#    drink  drinkability  drinkable  dry  feel  finger  finish  first  flavor  \
# 0     92            53         77   67    74      90     194     58     351
# 1    178           108        170  150   143     198     382    129     682
# 2    191            99         96   87   129     116     248     89     604
# 3    109           123        108  222   125     140     379     88     603
# 4    161            96        109  115   104     103     246     83     497
#
#    floral  fruit  full  glass   go  golden  good  grapefruit  great  head  \
# 0      25     47    30    168   87      38   326           3     90   509
# 1      19    135   102    390  122       2   639           1    171   955
# 2      18    501    25    262  113     167   384          24    103   655
# 3      32    480   104    271   71      10   473           4    147   780
# 4      32     93    47    302  119     185   448          22    142   679
#
#    hint  hop  hoppy  ipa  lacing  leaf  light  like  little  lot  make  malt  \
# 0   111  343     27    4     178    49    417   206     251   62    53   542
# 1   343  570     50    5     337    91    652   508     413  140   107  1034
# 2   179  180     13    7     219    45    694   627     346  127    97   295
# 3   254  252     19    0     276   112    411   370     352  121   103   696
# 4   188  348     41   12     243    59    572   470     366  103    76   251
#
#    malty  medium  mild  mouth  mouthfeel  much  nice  nose  note  orange  \
# 0    189     186   106     46        165   158   314    94   125      85
# 1    285     398   152     94        315   241   652   212   268      15
# 2     48     148    83     65        246   276   272   146   113     189
# 3    222     342   119     90        279   187   509   191   204      71
# 4     53     189   151     59        270   304   320   144   182     424
#
#    overall  pine  pint  poured  pours  pretty  quickly  quite  really  \
# 0      131     9    88      68     93     132       82     61     117
# 1      233     3   182     142    181     236      120    170     241
# 2      176     0   116     115    144     187      131    137     222
# 3      161     4    20     167    177     142       97    144     191
# 4      185     4    88     124    121     189       92     92     200
#
#    roasted  slight  slightly  smell  smooth  spice  still  stout  strong  \
# 0       58     120       135    256     129     33     62      3      30
# 1      456     198       204    567     254     29    115     68     115
# 2        0     172       156    571     110     19     83      3      96
# 3      117     142       187    410     201    255    111      7      96
# 4        3     141       117    458     178    155     80      3      71
#
#    style  sweet  sweetness  tan  taste  thick  thin  time  touch  vanilla  \
# 0     82    294        100   31    445     36   143    43     72        5
# 1    157    590        191  342    834    170   220    97    109       34
# 2     52    369         97    9    828     39   202    94     55        2
# 3    244    431        193  155    672    119   169    59     82       27
# 4    234    172         69   12    684     57   162    92     74        7
#
#    way  well  white
# 0   38   151    197
# 1  103   295    109
# 2   79   191    292
# 3   75   291    203
# 4   90   202    300

# %%
list(bag_of_word_df.columns.values)
# Out:
# ['alcohol',
#  'ale',
#  'almost',
#  'amber',
#  'aroma',
#  'balance',
#  'balanced',
#  'big',
#  'bit',
#  'bitter',
#  'bitterness',
#  'black',
#  'bodied',
#  'body',
#  'bottle',
#  'brew',
#  'brown',
#  'caramel',
#  'carbonation',
#  'chocolate',
#  'citrus',
#  'clear',
#  'coffee',
#  'color',
#  'creamy',
#  'dark',
#  'decent',
#  'definitely',
#  'drink',
#  'drinkability',
#  'drinkable',
#  'dry',
#  'feel',
#  'finger',
#  'finish',
#  'first',
#  'flavor',
#  'floral',
#  'fruit',
#  'full',
#  'glass',
#  'go',
#  'golden',
#  'good',
#  'grapefruit',
#  'great',
#  'head',
#  'hint',
#  'hop',
#  'hoppy',
#  'ipa',
#  'lacing',
#  'leaf',
#  'light',
#  'like',
#  'little',
#  'lot',
#  'make',
#  'malt',
#  'malty',
#  'medium',
#  'mild',
#  'mouth',
#  'mouthfeel',
#  'much',
#  'nice',
#  'nose',
#  'note',
#  'orange',
#  'overall',
#  'pine',
#  'pint',
#  'poured',
#  'pours',
#  'pretty',
#  'quickly',
#  'quite',
#  'really',
#  'roasted',
#  'slight',
#  'slightly',
#  'smell',
#  'smooth',
#  'spice',
#  'still',
#  'stout',
#  'strong',
#  'style',
#  'sweet',
#  'sweetness',
#  'tan',
#  'taste',
#  'thick',
#  'thin',
#  'time',
#  'touch',
#  'vanilla',
#  'way',
#  'well',
#  'white']

# %%
stop_words = stopwords.words('english')

# %%
tokenized_corpus = [word.lower() for sentence in corpus \
                    for word in word_tokenize(re.sub(r'([^\s\w]|_)+', ' ', sentence)) \
                    if word.lower() not in stop_words]

# %%
token_count_di = Counter(tokenized_corpus)
print('And the 100 most common words are...')
token_count_di.most_common(100)
# Out:
# And the 100 most common words are...
# [('beer', 1142833),
#  ('hop', 905447),
#  ('head', 857259),
#  ('malt', 752046),
#  ('taste', 737256),
#  ('flavor', 628865),
#  ('nice', 605515),
#  ('good', 558327),
#  ('like', 537809),
#  ('light', 510588),
#  ('sweet', 483215),
#  ('smell', 481698),
#  ('one', 463716),
#  ('aroma', 437327),
#  ('carbonation', 419456),
#  ('dark', 406510),
#  ('bit', 404813),
#  ('finish', 394313),
#  ('well', 388364),
#  ('glass', 362568),
#  ('little', 355657),
#  ('color', 334884),
#  ('medium', 334793),
#  ('lacing', 331255),
#  ('bottle', 328984),
#  ('chocolate', 321135),
#  ('mouthfeel', 305388),
#  ('white', 303654),
#  ('citrus', 293534),
#  ('note', 286817),
#  ('really', 285518),
#  ('body', 284962),
#  ('caramel', 278980),
#  ('brown', 277637),
#  ('alcohol', 271518),
#  ('great', 269775),
#  ('coffee', 258958),
#  ('bitterness', 255494),
#  ('bitter', 252703),
#  ('much', 249768),
#  ('orange', 247967),
#  ('pours', 247199),
#  ('smooth', 236853),
#  ('fruit', 235131),
#  ('nose', 232709),
#  ('would', 230024),
#  ('overall', 226243),
#  ('hint', 212753),
#  ('sweetness', 210009),
#  ('lot', 202036),
#  ('ipa', 197265),
#  ('pretty', 194342),
#  ('finger', 194039),
#  ('slightly', 183732),
#  ('amber', 182472),
#  ('dry', 180833),
#  ('roasted', 180054),
#  ('drink', 179986),
#  ('poured', 179007),
#  ('thick', 177353),
#  ('brew', 176365),
#  ('black', 176059),
#  ('creamy', 175672),
#  ('get', 173538),
#  ('quite', 170910),
#  ('ale', 167924),
#  ('big', 166234),
#  ('pine', 164222),
#  ('slight', 163723),
#  ('feel', 162626),
#  ('style', 160550),
#  ('thin', 159418),
#  ('strong', 158003),
#  ('bodied', 157784),
#  ('almost', 153536),
#  ('stout', 148792),
#  ('grapefruit', 147712),
#  ('full', 143486),
#  ('clear', 139456),
#  ('balanced', 138555),
#  ('first', 135788),
#  ('come', 135107),
#  ('also', 130639),
#  ('malty', 129690),
#  ('oz', 129354),
#  ('spice', 128343),
#  ('could', 127732),
#  ('still', 126573),
#  ('make', 124438),
#  ('golden', 124291),
#  ('hoppy', 123855),
#  ('vanilla', 122355),
#  ('balance', 121377),
#  ('way', 120217),
#  ('drinkable', 119743),
#  ('floral', 118666),
#  ('time', 116334),
#  ('tan', 114618),
#  ('definitely', 113573),
#  ('pint', 112913)]

# %%
#the above generated list is a good place to start for adding more stop words

# %%
frequencies = [b for (a,b) in token_count_di.most_common(10000)]
tokens = [a for (a,b) in token_count_di.most_common(10000)]
ranks = range(1, len(frequencies)+1)
plt.figure(figsize=(8,8))
plt.ylim(10**2,10**4)
plt.xlim(1,10**6)
#Actual ranks and frequencies
obtained_line, = loglog(ranks, frequencies, marker=".", label="Text Corpus")
obtained_legend = plt.legend(handles=[obtained_line], loc=1)
ax = plt.gca().add_artist(obtained_legend)
#Expected ranks and frequencies as per Zipf's law
expected_line, = plt.plot([1,frequencies[0]],[frequencies[0],1],color='r',label="Line expected as per Zipf's Law")
plt.legend(handles=[expected_line], loc=4)
title("Plot stating Zipf law's in log-log scale")
xlabel("Rank of token in descending order of frequency of occurrence")
ylabel("Frequency of ocurrence of token")
grid(True)

# %% [markdown]
# ## TF-IDF

# %%
#FEATURE EXTRACTION
#throw out any words used with 90% frequency or higher, throw out words that have been used less than 5 times
tfidf_model = TfidfVectorizer(max_features=100,
                             max_df=0.9,
                             min_df=5)

tfidf_matrix = tfidf_model.fit_transform(corpus).todense()

# %%
tfidf_matrix.shape
# Out:
# (1630, 100)

# %%
pd.set_option('display.max_columns', None)

# %%
tfidf_df = pd.DataFrame(tfidf_matrix)
tfidf_df.columns = sorted(tfidf_model.vocabulary_)
tfidf_df.head()
# Out:
#        adam       age      aged   apricot    banana  barleywine    barrel  \
# 0  0.062938  0.004445  0.000000  0.009346  0.009081    0.000000  0.000000
# 1  0.003861  0.002291  0.003406  0.000803  0.003900    0.002406  0.000000
# 2  0.006051  0.000000  0.000000  0.004354  0.006111    0.000000  0.001135
# 3  0.001634  0.022620  0.023418  0.011889  0.102318    0.002545  0.001992
# 4  0.006769  0.000837  0.000933  0.015831  0.300809    0.000000  0.002063
#
#       beige   belgian  biscuity    bomber     booze     boozy   bourbon  \
# 0  0.034118  0.008974  0.123703  0.000000  0.000000  0.009382  0.025023
# 1  0.028573  0.004625  0.005313  0.000000  0.003183  0.000000  0.006448
# 2  0.000442  0.003252  0.002287  0.000000  0.000000  0.000000  0.001295
# 3  0.046501  0.626253  0.019269  0.012218  0.020204  0.015344  0.002274
# 4  0.001605  0.008445  0.006652  0.005272  0.000000  0.000000  0.000000
#
#        burn    cherry  chocolate  cinnamon   citrusy    cloudy     clove  \
# 0  0.008825  0.018016   0.045181  0.023826  0.004289  0.034500  0.000000
# 1  0.003032  0.020117   0.754586  0.011460  0.004420  0.003704  0.002705
# 2  0.000914  0.006528   0.000520  0.000493  0.002664  0.069651  0.003804
# 3  0.009622  0.132595   0.348491  0.050226  0.007793  0.147334  0.221286
# 4  0.000000  0.000000   0.000945  0.004484  0.054078  0.273522  0.222262
#
#       coast     cocoa    coffee    copper  coriander      corn   crystal  \
# 0  0.000000  0.005973  0.043415  0.365357   0.000000  0.099249  0.089616
# 1  0.002609  0.064639  0.401810  0.004329   0.000000  0.011366  0.013929
# 2  0.000524  0.000000  0.000000  0.007391   0.000654  0.011988  0.002651
# 3  0.003680  0.069464  0.203160  0.065632   0.061961  0.010020  0.006204
# 4  0.012385  0.000000  0.000000  0.007113   0.032085  0.017641  0.001606
#
#        dipa    double  espresso       fig      funk      gold     grape  \
# 0  0.000000  0.000000  0.000000  0.005803  0.010628  0.069043  0.042490
# 1  0.000000  0.000821  0.021666  0.016947  0.002739  0.000000  0.009489
# 2  0.000701  0.000990  0.000000  0.000000  0.000550  0.022338  0.014077
# 3  0.002462  0.064284  0.005730  0.181379  0.021246  0.006273  0.055595
# 4  0.001275  0.003599  0.000000  0.000000  0.006001  0.059286  0.003199
#
#    grapefruit     grass      haze      hazy      heat  hoppiness       ipa  \
# 0    0.013802  0.046138  0.072771  0.124599  0.013034   0.046166  0.016965
# 1    0.000790  0.005764  0.008089  0.009595  0.002239   0.015140  0.003643
# 2    0.011431  0.005211  0.071352  0.108983  0.002699   0.001738  0.003074
# 3    0.006688  0.021342  0.028004  0.140542  0.001579   0.013728  0.000000
# 4    0.019049  0.022103  0.013696  0.156875  0.001635   0.009479  0.009579
#
#        ipas     juice     juicy     lager     lemon  licorice     mango  \
# 0  0.000000  0.034182  0.013196  0.764817  0.050863  0.017209  0.000000
# 1  0.000000  0.004404  0.001511  0.015925  0.001456  0.006898  0.000000
# 2  0.000000  0.015925  0.002733  0.041271  0.007021  0.000000  0.000614
# 3  0.002060  0.009318  0.004796  0.001685  0.033891  0.020849  0.000000
# 4  0.002133  0.028949  0.003312  0.020065  0.282393  0.000000  0.001116
#
#       maple      milk     mocha  molasses       nut    nutmeg     nutty  \
# 0  0.005360  0.005158  0.000000  0.026175  0.126032  0.006090  0.230868
# 1  0.003683  0.044300  0.030092  0.055757  0.107480  0.004185  0.124121
# 2  0.000555  0.001602  0.000000  0.000542  0.001398  0.000000  0.000885
# 3  0.023375  0.013122  0.012733  0.095134  0.094885  0.030989  0.090125
# 4  0.001009  0.001941  0.000000  0.000000  0.000847  0.004585  0.006437
#
#         oak       oil    opaque     peach      pear      peel   pilsner  \
# 0  0.000000  0.004434  0.004231  0.009762  0.038170  0.000000  0.023917
# 1  0.005956  0.004571  0.041426  0.000839  0.000000  0.001518  0.012326
# 2  0.000000  0.000918  0.005694  0.015666  0.000494  0.000915  0.008914
# 3  0.028804  0.001612  0.043054  0.010645  0.038151  0.022480  0.005216
# 4  0.000000  0.001669  0.020702  0.009187  0.010776  0.034923  0.018005
#
#        pine  pineapple     piney      plum    porter   pumpkin    raisin  \
# 0  0.038170   0.000000  0.004632  0.000000  0.016887  0.026579  0.025165
# 1  0.002186   0.000000  0.003183  0.014994  0.094766  0.001141  0.031125
# 2  0.000000   0.000000  0.000000  0.005847  0.000583  0.000000  0.000000
# 3  0.006166   0.005775  0.005051  0.175411  0.014321  0.004830  0.292679
# 4  0.003193   0.007975  0.003487  0.000000  0.000000  0.002501  0.000000
#
#    raspberry   reddish     resin  resinous      rind     roast   roasted  \
# 0   0.000000  0.070318  0.005194  0.000000  0.018822  0.016509  0.249199
# 1   0.004280  0.060399  0.002677  0.000000  0.000000  0.047266  0.336567
# 2   0.930605  0.015531  0.000000  0.000000  0.001949  0.000000  0.000000
# 3   0.018112  0.119268  0.005664  0.002009  0.008551  0.036000  0.182705
# 4   0.000000  0.000000  0.000978  0.000000  0.007971  0.000000  0.002426
#
#      roasty      ruby       rye       sam     silky     smoke     stone  \
# 0  0.082597  0.009585  0.005184  0.063371  0.016829  0.005280  0.000000
# 1  0.076621  0.107025  0.008906  0.004666  0.007950  0.012697  0.003026
# 2  0.000000  0.000496  0.001073  0.005155  0.000436  0.001640  0.000912
# 3  0.036024  0.146312  0.007537  0.001645  0.024466  0.024945  0.011205
# 4  0.000000  0.000000  0.002927  0.011075  0.003167  0.000000  0.000829
#
#       stout     straw     syrup  tangerine  tartness    toffee  tropical  \
# 0  0.013630  0.019787  0.008582   0.000000  0.008969  0.180901  0.000000
# 1  0.053074  0.001700  0.003686   0.000000  0.003081  0.275988  0.000000
# 2  0.001411  0.019974  0.008441   0.002286  0.032964  0.000892  0.001060
# 3  0.011559  0.005394  0.024954   0.000000  0.026078  0.100189  0.009306
# 4  0.002565  0.071689  0.000000   0.006235  0.013504  0.000811  0.002891
#
#      warmth      west     wheat    winter      wood     woody    yeasty  \
# 0  0.004218  0.010053  0.062954  0.014064  0.017519  0.017080  0.055033
# 1  0.005072  0.001727  0.013699  0.007248  0.009781  0.008802  0.007272
# 2  0.000437  0.001041  0.323715  0.001941  0.000907  0.000442  0.012272
# 3  0.022994  0.007308  0.033558  0.010223  0.038204  0.041903  0.150783
# 4  0.002381  0.010406  0.787517  0.001765  0.000000  0.000000  0.074893
#
#      yellow      zest
# 0  0.060938  0.013819
# 1  0.002243  0.002374
# 2  0.041009  0.002861
# 3  0.001582  0.008371
# 4  0.187599  0.030343

# %%
list(tfidf_df.columns.values)
# Out:
# ['adam',
#  'age',
#  'aged',
#  'apricot',
#  'banana',
#  'barleywine',
#  'barrel',
#  'beige',
#  'belgian',
#  'biscuity',
#  'bomber',
#  'booze',
#  'boozy',
#  'bourbon',
#  'burn',
#  'cherry',
#  'chocolate',
#  'cinnamon',
#  'citrusy',
#  'cloudy',
#  'clove',
#  'coast',
#  'cocoa',
#  'coffee',
#  'copper',
#  'coriander',
#  'corn',
#  'crystal',
#  'dipa',
#  'double',
#  'espresso',
#  'fig',
#  'funk',
#  'gold',
#  'grape',
#  'grapefruit',
#  'grass',
#  'haze',
#  'hazy',
#  'heat',
#  'hoppiness',
#  'ipa',
#  'ipas',
#  'juice',
#  'juicy',
#  'lager',
#  'lemon',
#  'licorice',
#  'mango',
#  'maple',
#  'milk',
#  'mocha',
#  'molasses',
#  'nut',
#  'nutmeg',
#  'nutty',
#  'oak',
#  'oil',
#  'opaque',
#  'peach',
#  'pear',
#  'peel',
#  'pilsner',
#  'pine',
#  'pineapple',
#  'piney',
#  'plum',
#  'porter',
#  'pumpkin',
#  'raisin',
#  'raspberry',
#  'reddish',
#  'resin',
#  'resinous',
#  'rind',
#  'roast',
#  'roasted',
#  'roasty',
#  'ruby',
#  'rye',
#  'sam',
#  'silky',
#  'smoke',
#  'stone',
#  'stout',
#  'straw',
#  'syrup',
#  'tangerine',
#  'tartness',
#  'toffee',
#  'tropical',
#  'warmth',
#  'west',
#  'wheat',
#  'winter',
#  'wood',
#  'woody',
#  'yeasty',
#  'yellow',
#  'zest']

# %% [markdown]
# Notice the descriptors present in the TF-IDF matrix, they are mostly descriptors such as "roasty", "tangerine", "tropical" and "biscuity". These are the words that I am after as they will differentiate beers the most.

# %%
#calculate the cosine similarity of the matrix
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse mapping of indices and beer names, and drop duplicate names, if any
indices = pd.Series(beer_200_text.index, index=beer_200_text['beer_name']).drop_duplicates()

# %% [markdown]
# ## Content Recommender

# %%
# Function that takes in beer name as input and gives recommendations 
def content_recommender(title, cosine_sim=cosine_sim, df=beer_200_text, indices=indices):
    # Obtain the index of the beer that matches the name
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    beer_indices = [i[0] for i in sim_scores]

    
    return beer_200_text[['brewery_name', 'beer_name']].iloc[beer_indices]

# %%
content_recommender('Two Hearted Ale')
# Out:
#                        brewery_name                     beer_name
# 611      Smuttynose Brewing Company  Smuttynose IPA "Finest Kind"
# 574   Boulder Beer / Wilderness Pub                      Mojo IPA
# 1072          Boulevard Brewing Co.               Single-Wide IPA
# 374           Avery Brewing Company    Avery India Pale Ale (IPA)
# 253      SweetWater Brewing Company                Sweetwater IPA
# 461        Founders Brewing Company                Centennial IPA
# 737                 Heavy Seas Beer         Loose Cannon Hop3 IPA
# 780         New England Brewing Co.                   Sea Hag IPA
# 456      Dark Horse Brewing Company   Dark Horse Crooked Tree IPA
# 969         Lakefront Brewery, Inc.                           IPA

# %% [markdown]
# Ok, this is pretty neat. Notice that Founders Brewing Company's Centennial IPA is a top recommendation. The brewer who forumlated Two Hearted Ale (input) at Bell's also formulated Founders' Centennial IPA. Both beers contain one variety of hop - Centennial and have a very similar taste profile.

# %%
content_recommender('Breakfast Stout')
# Out:
#                     brewery_name                            beer_name
# 426     AleSmith Brewing Company                       Speedway Stout
# 1409           Evil Twin Brewing              Imperial Biscotti Break
# 695        Terrapin Beer Company  W-n-B Coffee Oatmeal Imperial Stout
# 1468        Prairie Artisan Ales                                Bomb!
# 1372    AleSmith Brewing Company   Speedway Stout - Vietnamese Coffee
# 1383          Flying Dog Brewery           Kujo Imperial Coffee Stout
# 1161      Tröegs Brewing Company                      Java Head Stout
# 7            Redhook Ale Brewery           Redhook Double Black Stout
# 194   Dogfish Head Craft Brewery                        Chicory Stout
# 1520      Perennial Artisan Ales                    Sump Coffee Stout

# %% [markdown]
# Again, nice recommendations here. W-n-B Coffee Oatmeal Imperial Stout is definitely a beer I'd recommend if Breakfast Stout is a favorite. Speedway Stout is another that I would recommend especially if available.

# %%
content_recommender('90 Minute IPA')
# Out:
#                                brewery_name  \
# 1022       BridgePort Brewing Co. / Brewpub
# 1130             Dogfish Head Craft Brewery
# 234               Lagunitas Brewing Company
# 707                    Breckenridge Brewery
# 737                         Heavy Seas Beer
# 958               Mendocino Brewing Company
# 568            Great Divide Brewing Company
# 1114               Shipyard Brewing Company
# 984         Anderson Valley Brewing Company
# 169   Victory Brewing Company - Downingtown
#
#                                  beer_name
# 1022                              Hop Czar
# 1130                            Squall IPA
# 234                                Maximus
# 707                    471 Small Batch IPA
# 737                  Loose Cannon Hop3 IPA
# 958         Special Edition - Imperial IPA
# 568                              Titan IPA
# 1114  Pugsley's Signature Series: XXXX IPA
# 984                           Imperial IPA
# 169                HopDevil India Pale Ale

# %% [markdown]
# When searching a beer, the content recommender outputs mostly beers from the same style. This makes sense as it is built from the text reviews only, so it relies on the tf-idf matrix to make the recommendations. A hybrdized recommender could help diversify the outputs across styles by using the rating data within the dataset.

# %% [markdown]
# ## Collaborative Filter

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise.model_selection import RandomizedSearchCV
from surprise import KNNBasic, KNNWithMeans, KNNWithZScore
from surprise import SVD, SVDpp, NMF 
from surprise import SlopeOne, CoClustering
from surprise import accuracy

# %%
#something is up with beer_200_collab - double check the code. I might just need to change the user id threshold (user_count)

# %%
reader = Reader()

# %%
beer_200.head()
# Out:
#    beer_id         username        date  \
# 0   115317     KrajDoesBeer  2015-04-17
# 1   115317         Mmart802  2016-04-22
# 2   115317           Edmuzz  2016-04-15
# 3   115317          Lelandt  2016-04-07
# 4   115317  PittstopBrewing  2016-04-14
#
#                                                 text  look  smell  taste  \
# 0  10.24 batch. citra all in the nose.. some dank...  5.00   5.00    5.0
# 1  This beer was a real treat. Lots of sweet hop ...  5.00   4.75    5.0
# 2  This is a wonderful offering from MBC. While I...  5.00   4.75    5.0
# 3               Amazing. That's the only word for it  4.75   5.00    5.0
# 4  Most likely the best beer I have ever had. Sme...  5.00   5.00    5.0
#
#    feel  overall  score beer_name  brewery_id state country            style  \
# 0  4.75      5.0   4.98    Dinner       20681    ME      US  New England IPA
# 1  4.75      5.0   4.92    Dinner       20681    ME      US  New England IPA
# 2  4.75      5.0   4.92    Dinner       20681    ME      US  New England IPA
# 3  5.00      5.0   4.99    Dinner       20681    ME      US  New England IPA
# 4  5.00      5.0   5.00    Dinner       20681    ME      US  New England IPA
#
#   availability  abv                                         beer_notes  \
# 0     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 1     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 2     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 3     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
# 4     Rotating  8.2  Our first Double IPA – dry, refreshing and hop...
#
#   retired        brewery_name      city           brewery_notes  \
# 0       f  Maine Beer Company  Freeport  No notes at this time.
# 1       f  Maine Beer Company  Freeport  No notes at this time.
# 2       f  Maine Beer Company  Freeport  No notes at this time.
# 3       f  Maine Beer Company  Freeport  No notes at this time.
# 4       f  Maine Beer Company  Freeport  No notes at this time.
#
#                       types  \
# 0  Brewery, Bar, Beer-to-go
# 1  Brewery, Bar, Beer-to-go
# 2  Brewery, Bar, Beer-to-go
# 3  Brewery, Bar, Beer-to-go
# 4  Brewery, Bar, Beer-to-go
#
#                                    without_stopwords  \
# 0  10.24 batch. citra nose.. dankness well.. look...
# 1  This beer real treat. Lots sweet hop citrus no...
# 2  This wonderful offering MBC. While I'm huge fa...
# 3                               Amazing. That's word
# 4  Most likely best beer I ever had. Smell, look,...
#
#                                      lemmatized_text  review_count
# 0  batch citra nose dankness well look classic ha...           361
# 1  real treat lot sweet hop citrus note crisp dip...           361
# 2  wonderful offering mbc huge fan hype real hard...           361
# 3                                       amazing word           361
# 4          likely best ever smell look taste perfect           361

# %%
beer_200_collab = beer_200[['beer_id', 'overall', 'brewery_name', 'username', 'beer_name']]

# %%
beer_200_collab.username = pd.Categorical(beer_200_collab.username)

# %%
beer_200_collab['user_id'] = beer_200_collab.username.cat.codes

# %%
beer_200_collab.to_csv(r'F:\Datasets\beer_200_collab')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-219-651007b417c1> in <module>
# ----> 1 beer_200_collab.to_csv(r'F:\Datasets\beer_200_collab')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         libwriters.write_csv_rows(self.data, ix, self.nlevels,
# --> 315                                   self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
beer_200_collab = pd.read_csv(r'F:\Datasets\beer_200_collab')
beer_200_collab.head()
# Out:
#    Unnamed: 0  beer_id  overall        brewery_name         username  \
# 0           0   115317      5.0  Maine Beer Company     KrajDoesBeer
# 1           1   115317      5.0  Maine Beer Company         Mmart802
# 2           2   115317      5.0  Maine Beer Company           Edmuzz
# 3           3   115317      5.0  Maine Beer Company          Lelandt
# 4           4   115317      5.0  Maine Beer Company  PittstopBrewing
#
#   beer_name  user_id
# 0    Dinner    15606
# 1    Dinner    18242
# 2    Dinner     8801
# 3    Dinner    16067
# 4    Dinner    20737

# %%
beer_200_collab.describe()
# Out:
#           Unnamed: 0        beer_id        overall        user_id
# count  701004.000000  701004.000000  701004.000000  701004.000000
# mean   446034.519944   30674.068893       3.987393   27803.847765
# std    283000.239738   39217.794117       0.637329   15360.534513
# min         0.000000      17.000000       1.000000       0.000000
# 25%    205462.750000    1881.000000       3.750000   14504.000000
# 50%    419340.500000   17112.000000       4.000000   29030.000000
# 75%    672612.250000   47360.000000       4.500000   41114.000000
# max    986162.000000  317146.000000       5.000000   52998.000000

# %% [markdown]
# We can shrink down this dataset into something more manageable for model building. Especially since knn will be a top candidate.

# %%
#how many unique users left reviews?
beer_200_collab['user_id'].nunique()
# Out:
# 53000

# %%
#count the reviews left by users
beer_200_collab['user_count'] = beer_200_collab['user_id'].groupby(beer_200_collab['user_id']).transform('count')

# %%
#filter out those users who have not left at least 250 reviews
beer_200_collab = beer_200_collab[beer_200_collab.user_count >= 250]
beer_200_collab.describe()
# Out:
#              beer_id        overall        user_id     user_count
# count  354861.000000  354861.000000  354861.000000  354861.000000
# mean    30671.163926       3.900183   27865.538986     512.737852
# std     36680.407897       0.607655   15376.718691     219.890497
# min         5.000000       1.000000      37.000000     250.000000
# 25%      2009.000000       3.500000   14175.000000     342.000000
# 50%     20781.000000       4.000000   29155.000000     461.000000
# 75%     46793.000000       4.250000   41380.000000     627.000000
# max    317146.000000       5.000000   52962.000000    1289.000000

# %%
beer_200_collab['user_id'].nunique()
# Out:
# 809

# %%
#load the data for Surprise
data = Dataset.load_from_df(beer_200_collab[['user_id', 'beer_id', 'overall']], reader)

# %%
trainset = data.build_full_trainset()
testset = trainset.build_testset()

# %%
# Use the KNN algorithm
knn = KNNBasic()

# Run 5-fold cross-validation and then print results
knn_res = cross_validate(knn, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.4943  0.4902  0.4885  0.4917  0.4916  0.4912  0.0019
# MAE (testset)     0.3567  0.3540  0.3534  0.3554  0.3549  0.3549  0.0011
# Fit time          1.66    1.20    1.13    1.17    1.13    1.26    0.20
# Test time         7.08    6.80    6.87    6.75    6.64    6.83    0.15

# %%
# Use the KNN algorithm
knn_wm = KNNWithMeans()

# Run 5-fold cross-validation and then print results
knn_wm_res = cross_validate(knn_wm, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.4785  0.4819  0.4799  0.4871  0.4826  0.4820  0.0030
# MAE (testset)     0.3509  0.3523  0.3508  0.3559  0.3548  0.3530  0.0021
# Fit time          1.20    1.24    1.18    1.18    1.17    1.19    0.02
# Test time         7.36    7.37    6.95    7.16    6.92    7.15    0.19

# %%
# Use the SVD algorithm
svd = SVD()

# Run 5-fold cross-validation and then print results
svd_res = cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.4776  0.4787  0.4756  0.4777  0.4823  0.4784  0.0022
# MAE (testset)     0.3480  0.3489  0.3488  0.3488  0.3531  0.3495  0.0018
# Fit time          7.89    8.51    8.75    10.71   10.10   9.19    1.05
# Test time         0.30    0.30    0.30    0.34    0.48    0.34    0.07

# %%
# Use the SVDpp algorithm
svdpp = SVDpp()

# Run 5-fold cross-validation and then print results 
svdpp_res = cross_validate(svdpp, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.4681  0.4691  0.4778  0.4758  0.4755  0.4732  0.0039
# MAE (testset)     0.3423  0.3434  0.3483  0.3466  0.3460  0.3453  0.0022
# Fit time          594.02  591.60  591.53  628.26  667.22  614.53  29.80
# Test time         10.48   10.58   11.22   12.49   12.36   11.42   0.86

# %%
x_algo = ['KNN Basic', 'KNN Means', 'SVD', 'SVDpp']
all_algos_cv = [knn_res, knn_wm_res, svd_res, svdpp_res]

rmse_cv = [round(res['test_rmse'].mean(), 4) for res in all_algos_cv]
mae_cv = [round(res['test_mae'].mean(), 4) for res in all_algos_cv]

plt.figure(figsize=(20,5))

plt.subplot(1, 2, 1)
plt.title('Comparison of Algorithms on RMSE', loc='center', fontsize=15)
plt.plot(x_algo, rmse_cv, label='RMSE', color='darkgreen', marker='o')
plt.xlabel('Algorithms', fontsize=15)
plt.ylabel('RMSE Value', fontsize=15)
plt.legend()
plt.grid(ls='dashed')

plt.subplot(1, 2, 2)
plt.title('Comparison of Algorithms on MAE', loc='center', fontsize=15)
plt.plot(x_algo, mae_cv, label='MAE', color='navy', marker='o')
plt.xlabel('Algorithms', fontsize=15)
plt.ylabel('MAE Value', fontsize=15)
plt.legend()
plt.grid(ls='dashed')

plt.show()

# %% [markdown]
# Considering how long it took to run the SVDpp model, I think SVD is our best bet. Let's fine tune it and see how accurate it can become.

# %%
#tune the parameters with a GridSearch
svd_param_grid = {'n_epochs': [20, 25, 30],
                  'n_factors':[50,100,150],
                  'lr_all': [0.007, 0.009, 0.01],
                  'reg_all': [0.2, 0.4, 0.6]}

svd_gs = GridSearchCV(SVD, svd_param_grid, measures=['rmse', 'mae'], cv=5, n_jobs=5)
svd_gs.fit(data)

# %%
svd_gs.best_params
# Out:
# {'rmse': {'n_epochs': 30, 'n_factors': 150, 'lr_all': 0.007, 'reg_all': 0.2},
#  'mae': {'n_epochs': 30, 'n_factors': 150, 'lr_all': 0.007, 'reg_all': 0.2}}

# %%
print(svd_gs.best_score['rmse'])
print(svd_gs.best_score['mae'])
# Out:
# 0.4788962671716357
# 0.3511820928870556

# %%
n_epochs = [30, 60, 90]
n_factors = [150, 300, 450]
lr_all = [0.002, 0.005, 0.007]
reg_all = [0.05, 0.1, 0.2]


random_grid = {'n_epochs': n_epochs,
               'n_factors': n_factors,
               'lr_all': lr_all,
               'reg_all': reg_all}

# %%
svd_random = RandomizedSearchCV(SVD, random_grid, measures = ['rmse', 'mae'],
                                cv = 5, random_state=42)
svd_random.fit(data)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     796             try:
# --> 797                 tasks = self._ready_batches.get(block=False)
#     798             except queue.Empty:
#
# ~\Anaconda3\lib\queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-aa7520b7a079> in <module>
#       1 svd_random = RandomizedSearchCV(svd, random_grid, measures = ['rmse', 'mae'],
#       2                                 cv = 5, random_state=42)
# ----> 3 svd_random.fit(data)
#
# ~\Anaconda3\lib\site-packages\surprise\model_selection\search.py in fit(self, data)
#      88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
# ---> 90                        verbose=self.joblib_verbose)(delayed_list)
#      91
#      92         (test_measures_dicts,
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     806                 big_batch_size = batch_size * n_jobs
#     807
# --> 808                 islice = list(itertools.islice(iterator, big_batch_size))
#     809                 if len(islice) == 0:
#     810                     return False
#
# ~\Anaconda3\lib\site-packages\surprise\model_selection\search.py in <genexpr>(.0)
#      83                                    testset, self.measures,
#      84                                    self.return_train_measures)
# ---> 85             for params, (trainset, testset) in product(self.param_combinations,
#      86                                                        cv.split(data))
#      87         )
#
# TypeError: 'SVD' object is not callable

# %%
svd_random.best_params
# Out:
# {'rmse': {'n_epochs': 90, 'n_factors': 450, 'lr_all': 0.005, 'reg_all': 0.05},
#  'mae': {'n_epochs': 90, 'n_factors': 450, 'lr_all': 0.005, 'reg_all': 0.05}}

# %%
svd_random = svd_random.best_params

# %%
print(svd_random.best_score['rmse'])
print(svd_random.best_score['mae'])
# Out:
# 0.4681694895375383
# 0.3434564813155974

# %%
# Use the SVD algorithm
svd_best = SVD(n_epochs=90, n_factors=450, lr_all=0.005, reg_all=0.05)
  
svd_best_res = cross_validate(svd_best, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.4695  0.4743  0.4679  0.4641  0.4678  0.4687  0.0033
# MAE (testset)     0.3416  0.3450  0.3410  0.3386  0.3406  0.3414  0.0021
# Fit time          195.65  177.84  180.06  193.39  199.53  189.29  8.70
# Test time         0.37    0.23    0.39    0.25    0.43    0.33    0.08

# %%
import pickle

filename = 'svd_random.sav'
pickle.dump(svd_random, open(filename, 'wb'))

# %%
import pickle

filename = 'svdpp.sav'
pickle.dump(svdpp, open(filename, 'wb'))

# %%
svd_best.predict(46, 5121, 6)
# Out:
# Prediction(uid=46, iid=5121, r_ui=6, est=3.9365111631753034, details={'was_impossible': False})

# %% [markdown]
# ## Hybrid Recommender

# %%
#beer id df to extract from
beer_ids = beer_200_collab[['beer_name', 'beer_id', 'user_id', 'brewery_name']]
beer_ids.head()
# Out:
#   beer_name  beer_id  user_id        brewery_name
# 0    Dinner   115317    15606  Maine Beer Company
# 1    Dinner   115317    18242  Maine Beer Company
# 2    Dinner   115317     8801  Maine Beer Company
# 3    Dinner   115317    16067  Maine Beer Company
# 4    Dinner   115317    20737  Maine Beer Company

# %%
#drop duplicates
beer_ids = beer_ids.drop_duplicates(subset=['beer_name', 'beer_id'], keep='first')

# %%
#reset index
beer_ids = beer_ids.reset_index()

# %%
#rename columns
beer_ids = beer_ids.rename(columns={'index': 'id'})
beer_ids.head()
# Out:
#      id                   beer_name  beer_id  user_id        brewery_name
# 0     0                      Dinner   115317    15606  Maine Beer Company
# 1   361                       Lunch    68916     5115  Maine Beer Company
# 2  1303  A Tiny Beautiful Something   113339    44298  Maine Beer Company
# 3  1677                      Peeper    51512     7339  Maine Beer Company
# 4  2339                  King Titus    85822    16436  Maine Beer Company

# %%
beer_ids.to_csv(r'F:\Datasets\beer_ids.csv')

# %%
beer_ids = pd.read_csv(r'F:\Datasets\beer_ids.csv')

# %%
id_map = beer_ids
id_to_name = id_map.set_index('id')
name_to_id = id_map.set_index('beer_name')

# %%
user_id = beer_200_collab['user_id']

# %%
def hybrid(user_id, title):
    idx = indices[title]
    
    tnid = name_to_id.loc[title]['beer_id']
    beer_id = name_to_id.loc[title]['id']
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    beer_indices = [i[0] for i in sim_scores]
    
    beers = beer_ids.iloc[beer_indices][['beer_name', 'brewery_name', 'beer_id', 'id']]
    beers['est'] = beers['id'].apply(lambda x: svd_best.predict(user_id, id_to_name.loc[x]['beer_id']).est)
    beers = beers.sort_values('est', ascending=False)
    return beers.head(10)

# %%
hybrid(34092, 'Bud Light')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ecc0c571eb31> in <module>
# ----> 1 hybrid(34092, 'Bud Light')
#
# NameError: name 'hybrid' is not defined

# %%
hybrid(9657, 'Two Hearted Ale')
# Out:
#                                      beer_name                   brewery_name  \
# 657                          The Event Horizon           Olde Hickory Brewery
# 826                                   Vicinity       Trillium Brewing Company
# 461                       Sunday Morning Stout        Weyerbacher Brewing Co.
# 456                               Saison-Brett          Boulevard Brewing Co.
# 653                                        IPA       AleSmith Brewing Company
# 374                     Brewhouse Coffee Stout     Central Waters Brewing Co.
# 737                             Hoponius Union            Jack's Abby Brewing
# 449  Bourbon Barrel Quad Barrel-Aged Ale (BBQ)          Boulevard Brewing Co.
# 253                              Baltic Porter  The Duck-Rabbit Craft Brewery
# 969                  668 Neighbor Of The Beast        New England Brewing Co.
#
#      beer_id      id       est
# 657    64226  621352  4.412054
# 826   145496  771488  4.395805
# 461    89345  428231  4.330975
# 456    36333  424230  4.322379
# 653     3916  617326  4.320003
# 374    35930  356243  4.280599
# 737    71820  691332  4.276804
# 449    43670  420123  4.172480
# 253    32180  238002  4.155490
# 969    58731  907232  4.005760

# %%
hybrid(10170, 'Two Hearted Ale')
# Out:
#                                      beer_name                   brewery_name  \
# 657                          The Event Horizon           Olde Hickory Brewery
# 826                                   Vicinity       Trillium Brewing Company
# 456                               Saison-Brett          Boulevard Brewing Co.
# 653                                        IPA       AleSmith Brewing Company
# 461                       Sunday Morning Stout        Weyerbacher Brewing Co.
# 737                             Hoponius Union            Jack's Abby Brewing
# 374                     Brewhouse Coffee Stout     Central Waters Brewing Co.
# 449  Bourbon Barrel Quad Barrel-Aged Ale (BBQ)          Boulevard Brewing Co.
# 253                              Baltic Porter  The Duck-Rabbit Craft Brewery
# 969                  668 Neighbor Of The Beast        New England Brewing Co.
#
#      beer_id      id       est
# 657    64226  621352  4.348099
# 826   145496  771488  4.295432
# 456    36333  424230  4.267272
# 653     3916  617326  4.262768
# 461    89345  428231  4.249732
# 737    71820  691332  4.242807
# 374    35930  356243  4.232195
# 449    43670  420123  4.075476
# 253    32180  238002  4.033859
# 969    58731  907232  3.952548

# %% [markdown]
# Welp, I did it. I built a hybrid recommender that actually works and spits out some solid recommendations. Might be time to start cleaning up the notebook, leaving commentary where necessary. Also, edit the hybrid recommender to also say the brewery.
#
# To finish this up, go back and tune the models to the best RMSE/MAE values we can get and visualize the scores. Use the best performing algorithm (most likely SVD), tune it, then apply it to the recommender. Then polish up the notebook, turn it in and start working on the presentation.

# %% [markdown]
# Questions for Don:
#
# When shrinking the beer_200_collab data, how best to do it? Take a random sample? Or filter the number of reviewers by number of reviews left?
